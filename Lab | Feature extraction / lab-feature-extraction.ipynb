# %%
import scipy.stats as st
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('categorical.csv')
data.head()
# Out:
#         state response  coverage education employmentstatus gender  \
# 0  Washington       No     Basic  Bachelor         Employed      F
# 1     Arizona       No  Extended  Bachelor       Unemployed      F
# 2      Nevada       No   Premium  Bachelor         Employed      F
# 3  California       No     Basic  Bachelor       Unemployed      M
# 4  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status     policy renew_offer_type sales_channel  \
# 0      Suburban        Married  Corporate           Offer1         Agent
# 1      Suburban         Single   Personal           Offer3         Agent
# 2      Suburban        Married   Personal           Offer1         Agent
# 3      Suburban        Married  Corporate           Offer1   Call Center
# 4         Rural         Single   Personal           Offer1         Agent
#
#    vehicle_class vehicle_size
# 0   Two-Door Car      Medsize
# 1  Four-Door Car      Medsize
# ...

# %%
## PLOT ALL COLUMNS

# %%
def plot(dataframe):
    for column in dataframe.columns:
        sns.histplot(x=column, data=dataframe)
        plt.show()

# %%
plot(data)

# %%
def clean_redundant(df):
    for column in df.columns:
        if df[column].nunique()==1:
            df.drop(column, axis=1, inplace=True)
    return df 

## I create this function to check for redundant columns (unique values = 1)and drop if present.

# %%
data['response'].nunique()
# Out:
# 2

# %%
clean_redundant(data) ## APPLY the Function
# Out:
#            state response  coverage education employmentstatus gender  \
# 0     Washington       No     Basic  Bachelor         Employed      F
# 1        Arizona       No  Extended  Bachelor       Unemployed      F
# 2         Nevada       No   Premium  Bachelor         Employed      F
# 3     California       No     Basic  Bachelor       Unemployed      M
# 4     Washington       No     Basic  Bachelor         Employed      M
# ...          ...      ...       ...       ...              ...    ...
# 9129  California       No     Basic  Bachelor         Employed      M
# 9130  California      Yes  Extended   College         Employed      F
# 9131  California       No  Extended  Bachelor       Unemployed      M
# 9132  California       No  Extended   College         Employed      M
# 9133  California       No  Extended   College       Unemployed      M
#
#      location_code marital_status     policy renew_offer_type sales_channel  \
# ...

# %%
#sns.histplot(x='time_variable', data=data)
#plt.show()

## but no time variable found, !!HELP!!
