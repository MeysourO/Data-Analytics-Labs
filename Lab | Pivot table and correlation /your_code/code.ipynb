# %% [markdown]
# # Before you start :
#    - These exercises are related to the Pivot table and correlation lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# your answer here
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Open the ` Employee.csv` file and name your dataset `employee`.

# %%
# your answer here
employee = pd.read_csv('data/Employee.csv')
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### What's the mean salary by department?
# Hint : There are 2 ways to do it - one way is with groupby and the other way is with pivot tables. Do it both ways.

# %%
# Method 1
# your answer here
employee.groupby(['Department']).agg({'Salary':'mean'})
# Out:
#             Salary
# Department
# HR           45.00
# IT           48.75
# Sales        55.00

# %% [markdown]
# #### We want now to group the data by more than one column. Use Pandas pivot table function to select the mean salary by department and title.

# %%
# Method 2
# your answer here
df = employee.pivot_table(index= ['Title','Department'], values = ['Salary'], aggfunc = {'Salary':'mean'}).reset_index()

# %%
# your answer here
df
# Out:
#        Title Department  Salary
# 0         VP         HR    70.0
# 1         VP         IT    70.0
# 2    analyst         HR    32.5
# 3    analyst         IT    32.5
# 4  associate         IT    60.0
# 5  associate      Sales    55.0

# %% [markdown]
# #### We want to display the number of years of work experience and the salary for each Title. Add Years as a column in your pivot table.
# *Hint: Use Pandas doc(see References in README.md) to explore the pivot_table() arguments*

# %%
df = employee.pivot_table(index= ['Title','Department','Years'], values = ['Salary'], aggfunc = {'Salary':'mean'}).reset_index()
df
# Out:
#        Title Department  Years  Salary
# 0         VP         HR      8      70
# 1         VP         IT      8      70
# 2    analyst         HR      2      30
# 3    analyst         HR      4      35
# 4    analyst         IT      1      35
# 5    analyst         IT      2      30
# 6  associate         IT      7      60
# 7  associate      Sales      2      55
# 8  associate      Sales      3      55

# %% [markdown]
# #### We want to know the information about the mean salary and number of employees in each department and for each job title.

# %%
# your answer here
df = employee.pivot_table(index= ['Title','Department'], values = ['Salary','Name'], aggfunc = {'Salary':'mean','Name':'count'}).reset_index()
df
# Out:
#        Title Department  Name  Salary
# 0         VP         HR     1    70.0
# 1         VP         IT     1    70.0
# 2    analyst         HR     2    32.5
# 3    analyst         IT     2    32.5
# 4  associate         IT     1    60.0
# 5  associate      Sales     2    55.0

# %% [markdown]
# #### We want to know for each department and for each job title the Salary's median, minimum, maximum and standard deviation. Comment your results.

# %%
# your answer here
df = employee.pivot_table(index= ['Title','Department'], values = ['Salary'],aggfunc={'mean','min','max','std'})
df

#Nan value because only 1 value. std=0
# Out:
#                      Salary
#                         max  mean min       std
# Title     Department
# VP        HR             70  70.0  70       NaN
#           IT             70  70.0  70       NaN
# analyst   HR             35  32.5  30  3.535534
#           IT             35  32.5  30  3.535534
# associate IT             60  60.0  60       NaN
#           Sales          55  55.0  55  0.000000

# %% [markdown]
# #### Based on your comments, fill the missing values with an appropriate value.

# %%
# your answer here
df = df.fillna(0)
df
# Out:
#                      Salary
#                         max  mean min       std
# Title     Department
# VP        HR             70  70.0  70  0.000000
#           IT             70  70.0  70  0.000000
# analyst   HR             35  32.5  30  3.535534
#           IT             35  32.5  30  3.535534
# associate IT             60  60.0  60  0.000000
#           Sales          55  55.0  55  0.000000

# %% [markdown]
# #### The stake holders want to know for each department the number of employees and how much money is spend on salaries. Could you provide that information?

# %%
# your answer here
df = employee.pivot_table(index= ['Department'], values = ['Salary','Name'], aggfunc = {'Salary':'mean','Name':'count'}).reset_index()
df
# Out:
#   Department  Name  Salary
# 0         HR     3   45.00
# 1         IT     4   48.75
# 2      Sales     2   55.00

# %% [markdown]
# #### For each Department and Title, we want to know the the total years of work experience and the mean salary.

# %%
# your answer here
df = employee.pivot_table(index= ['Title','Department'], values = ['Salary','Years'], aggfunc = {'Salary':'mean','Years':'count'}).reset_index()
df
# Out:
#        Title Department  Salary  Years
# 0         VP         HR    70.0      1
# 1         VP         IT    70.0      1
# 2    analyst         HR    32.5      2
# 3    analyst         IT    32.5      2
# 4  associate         IT    60.0      1
# 5  associate      Sales    55.0      2

# %% [markdown]
# ### Bonus
#
# #### We now want to compute the mean salary after removing the maxima for each Department. Create the appropriate pivot table.
#
# Hint: Write a custom function.

# %%
# your answer here

employee1 = employee[employee["Salary"] != employee.groupby("Department")["Salary"].transform(max)]
employee1
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 0   Jose         IT  Bachelor      M    analyst      1      35
# 1  Maria         IT    Master      F    analyst      2      30
# 2  David         HR    Master      M    analyst      2      30
# 3  Sonia         HR  Bachelor      F    analyst      4      35
# 7  Pedro         IT       Phd      M  associate      7      60

# %%
employee1 = pd.concat([employee1, employee[employee["Department"]=="Sales"]])
employee1
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 7   Pedro         IT       Phd      M  associate      7      60
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55

# %%
# your answer here
# your answer here
df1 = employee1.pivot_table(index= ['Department'], values = ['Salary','Name'], aggfunc = {'Salary':'mean','Name':'count'}).reset_index()
df1
# Out:
#   Department  Name     Salary
# 0         HR     2  32.500000
# 1         IT     3  41.666667
# 2      Sales     2  55.000000
