# %% [raw]
# lab-web-scraping-single-page

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import pickle 
import random
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler

from matplotlib.lines import Line2D

# %%
# 2. find url and store it in a variable
url = "http://www.popvortex.com/music/charts/top-100-songs.php"

# %%
# 3. download html with a get request
response = requests.get(url)
response.status_code # 200 status code means OK!
# Out:
# 200

# %%
# 4.1. parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")
#soup

# %%
soup.select('#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p')
# Out:
# [<p class="title-artist"><cite class="title">FLOWER</cite><em class="artist">JISOO</em></p>]

# %%
soup.select('div.chart-content.col-xs-12.col-sm-8 > p > cite')[2].get_text()
# Out:
# 'Flowers'

# %%
soup.select('div.chart-content.col-xs-12.col-sm-8 > p > em')[1].get_text()
# Out:
# 'Morgan Wallen'

# %%
# define the number of iterations of our for loop
# by checking how many elements are in the retrieved result set
# (this is equivalent but more robust than just explicitly defining 250 iterations)
num_iter = len(soup.select('div.chart-content.col-xs-12.col-sm-8 > p > cite'))
num_iter
# Out:
# 100

# %%
tClist = soup.select('div.chart-content.col-xs-12.col-sm-8 > p > cite')
spanlist = soup.select('div.chart-content.col-xs-12.col-sm-8 > p > em')

# %%
len(tClist)
# Out:
# 100

# %%
len(spanlist)
# Out:
# 100

# %%
# iterate through the result set and retrive all the data
title = []
artist = []
for i in range(num_iter):

    title.append(tClist[i].get_text())

    artist.append(spanlist[i].get_text())



print(title)
print(artist)
# Out:
# ['FLOWER', 'Last Night', 'Flowers', 'Fast Car', 'Thank God I Do', 'Like Crazy (Deep House Remix)', 'Like Crazy (UK Garage Remix)', 'Calm Down', 'Like Crazy (Instrumental)', 'Like Crazy (English Version)', 'You Say', 'Like Crazy', 'Anti-Hero', 'Eyes Closed', 'Heart Like A Truck', 'All Eyes On Me', 'Thinkin’ Bout Me', 'Master of War', 'Players', 'Thought You Should Know', 'Lavender Haze (Acoustic Version)', "God's Country", 'Thank God', 'TRUSTFALL', 'Rock and a Hard Place', 'Love You Anyway', "Growin' Up and Gettin' Old", 'Fighting Myself', 'Kill Bill', 'Red Ruby Da Sleeze (Sped Up) [feat. Xxtristanxo & Speed Radio]', '72 Seasons', 'labour', 'NASTY', 'wait in the truck', 'Favorite Song', '5 Leaf Clover', 'SORRY NOT SORRY', 'Wasted On You', "I Ain't Worried", 'Rescue', 'That’s Not How This Works (feat. Dan + Shay)', 'Unstoppable', 'Jesus and Jesse James', 'One Thing At A Time', 'Sure Thing', 'NASTY (Extended Version)', 'Set Me Free, Pt. 2', 'Face-off', 'NEED A FAVOR', "Something in the 
# ...

# %%
# each list becomes a column
songs = pd.DataFrame({"title":title,
                    "artist":artist})

# %%
songs
# Out:
#                  title                     artist
# 0               FLOWER                      JISOO
# 1           Last Night              Morgan Wallen
# 2              Flowers                Miley Cyrus
# 3             Fast Car                 Luke Combs
# 4       Thank God I Do              Lauren Daigle
# ..                 ...                        ...
# 95      Out of My Head                   Fastball
# 96     I'm Good (Blue)  David Guetta & Bebe Rexha
# 97       Lavender Haze               Taylor Swift
# 98         Eyes Closed                 Ed Sheeran
# 99  Red Ruby Da Sleeze                Nicki Minaj
#
# [100 rows x 2 columns]

# %% [raw]
# Music recommendor :

# %%
song_title = input ('please insert song name:')
song_artist = input('please insert artist: ')
# Out:
# please insert song name:
# please insert artist:

# %%
x = random.randint(0,100)
# check if the song is in the DataFrame
if song_title in songs['title'].values:
    # if the song is in the DataFrame, recommend a different song
    recommended_song = songs.loc[songs['title'] != song_title, 'title'].iloc[x]
    print("You might like:", recommended_song)
else:
    # if the song is not in the DataFrame, print a message
    # send one song to spotipy and get back features for one song
    # that's the new input song 
    print("Sorry, we cannot recommend a song.")
    
if song_artist in songs['artist'].values:
    recommended_artist = songs.loc[songs['artist'] != song_artist, 'artist'].iloc[x]
    print ("You might like:", recommended_artist)
else: 
    print("Sorry,we cannot recommend an artist.")
# Out:
# Sorry, we cannot recommend a song.
# Sorry,we cannot recommend an artist.

# %% [raw]
# Lab | API wrappers - Create your collection of songs & audio features

# %%
# Getting the id and secret from spotify 

client_id = ''
client_secret = ''

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
#Playlist 
playlist_id = '0YnhI0DZoJBdygCRThNS2f'

# %%
# we will use our 'first paid music' playlist as an example:
playlist = sp.user_playlist_tracks("spotify", playlist_id)
len(playlist)
# Out:
# 7

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/0YnhI0DZoJBdygCRThNS2f/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2021-02-17T03:49:28Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/mittecar000'},
#     'href': 'https://api.spotify.com/v1/users/mittecar000',
#     'id': 'mittecar000',
#     'type': 'user',
#     'uri': 'spotify:user:mittecar000'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1G9G7WwrXka3Z1r7aIDjI7'},
#        'href': 'https://api.spotify.com/v1/artists/1G9G7WwrXka3Z1r7aIDjI7',
#        'id': '1G9G7WwrXka3Z1r7aIDjI7',
#        'name': 'Outkast',
#        'type': 'artist',
#        'uri': 'spotify:artist:1G9G7WwrXka3Z1r7aIDjI7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
# ...

# %%
# Let's look at items and total:
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist['total']
# Out:
# 4032

# %%
len(playlist["items"])
# Out:
# 100

# %%
from random import randint
from time import sleep

# %% [raw]
# Getting the playlist tracks

# %%
def get_playlist_tracks(playlist_id):
    results = sp.playlist_tracks(playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
playlist_tracks = get_playlist_tracks(playlist_id)
len(playlist_tracks)

#playlist_tracks
# Out:
# 4032

# %%
playlist_tracks[56]['track']['name']
# Out:
# 'Sorry'

# %% [raw]
# Getting songs uri

# %%
song_uri = []

for i in range(len(playlist_tracks)):
    song_uri.append(playlist_tracks[i]['track']['id'])

# %% [raw]
# Getting the audio features

# %%
audio_features = []

for i in range(len(playlist_tracks)):
    
    audio_features.append(sp.audio_features(song_uri[i]))

# %% [raw]
# Getting the artists names

# %%
artists = []

for i in range(len(playlist_tracks)):
    artists.append(playlist_tracks[i]['track']['album']['artists'][0]['name'])

# %%
len(artists)
# Out:
# 4032

# %% [raw]
# Getting the track name

# %%
Track_name = []
for i in range(len(playlist_tracks)):
    Track_name.append(playlist_tracks[i]['track']['name'])

# %%
len(Track_name)
# Out:
# 4032

# %%
# Make sure all lists have the same length
len(Track_name) == len(artists) == len(song_uri) == len(audio_features)
# Out:
# True

# %%
data = {
    'Track': Track_name ,
    'Artist': artists,
    'URI': song_uri,
    'Audio Features': audio_features
}


df = pd.DataFrame(data)

# %%
df
# Out:
#                                                   Track  \
# 0                       Southernplayalisticadillacmuzik
# 1     Learn How to Watch (feat. Mac Miller & MadeinTYO)
# 2                      Allegations (feat. Pooh Shiesty)
# 3                                          No Profanity
# 4                                             All Black
# ...                                                 ...
# 4027                                 Still Ridin' Clean
# 4028  Stay Fly (feat. Slim Thug, Trick Daddy & Proje...
# 4029                               I've Been Everywhere
# 4030                                    Cheese and Dope
# 4031                                           DOGTOOTH
#
#                            Artist                     URI  \
# 0                         Outkast  2pMAmZdHfQHyqJCXJbfhK3
# 1                         Carnage  5tErNrwK58SgLMjZXJ5fdY
# 2                           BIG30  3oW1FNqsSJVgxjE9rqgpDX
# ...

# %%
df['Audio Features'].value_counts()
# Out:
# [{'danceability': 0.691, 'energy': 0.834, 'key': 10, 'loudness': -5.802, 'mode': 0, 'speechiness': 0.225, 'acousticness': 0.0161, 'instrumentalness': 0, 'liveness': 0.0559, 'valence': 0.579, 'tempo': 172.387, 'type': 'audio_features', 'id': '2pMAmZdHfQHyqJCXJbfhK3', 'uri': 'spotify:track:2pMAmZdHfQHyqJCXJbfhK3', 'track_href': 'https://api.spotify.com/v1/tracks/2pMAmZdHfQHyqJCXJbfhK3', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2pMAmZdHfQHyqJCXJbfhK3', 'duration_ms': 317507, 'time_signature': 4}]          1
# ...

# %%
df2 = pd.json_normalize(df['Audio Features'])

# %%
type(df2[0][0])
# Out:
# 'audio_features'

# %%
df2[0][0]['danceability']
# Out:
# 0.691

# %%
def dance(features):
    return features['danceability']

# %%
df2['danceability'] = df2[0].apply(dance)

# %%
df2
# Out:
#                                                       0  danceability
# 0     {'danceability': 0.691, 'energy': 0.834, 'key'...         0.691
# 1     {'danceability': 0.547, 'energy': 0.737, 'key'...         0.547
# 2     {'danceability': 0.664, 'energy': 0.42, 'key':...         0.664
# 3     {'danceability': 0.701, 'energy': 0.571, 'key'...         0.701
# 4     {'danceability': 0.849, 'energy': 0.834, 'key'...         0.849
# ...                                                 ...           ...
# 4027  {'danceability': 0.885, 'energy': 0.697, 'key'...         0.885
# 4028  {'danceability': 0.792, 'energy': 0.899, 'key'...         0.792
# 4029  {'danceability': 0.731, 'energy': 0.779, 'key'...         0.731
# 4030  {'danceability': 0.883, 'energy': 0.849, 'key'...         0.883
# 4031  {'danceability': 0.706, 'energy': 0.648, 'key'...         0.706
#
# [4032 rows x 2 columns]

# %%
def energy(features):
    return features['energy']
df2['energy'] = df2[0].apply(energy)

# %%
def key(features):
    return features['key']
df2['key'] = df2[0].apply(key)

# %%
def loud(features):
    return features['loudness']
df2['loudness'] = df2[0].apply(loud)

# %%
def mode(features):
    return features['mode']
df2['mode'] = df2[0].apply(mode)

# %%
def speechiness(features):
    return features['speechiness']
df2['speechiness'] = df2[0].apply(speechiness)

# %%
def acousticness(features):
    return features['acousticness']
df2['acousticness'] = df2[0].apply(acousticness)

# %%
def instrumentalness(features):
    return features['instrumentalness']
df2['instrumentalness'] = df2[0].apply(instrumentalness)

# %%
def liveness(features):
    return features['liveness']
df2['liveness'] = df2[0].apply(liveness)

# %%
def valence(features):
    return features['valence']
df2['valence'] = df2[0].apply(valence)

# %%
def tempo(features):
    return features['tempo']
df2['tempo'] = df2[0].apply(tempo)

# %%
def duration_ms(features):
    return features['duration_ms']
df2['duration_ms'] = df2[0].apply(duration_ms)

# %%
def time_signature(features):
    return features['time_signature']
df2['time_signature'] = df2[0].apply(time_signature)

# %%
#df2=df2.drop('uri', axis=1)

# %%
#df2=df2.drop('id', axis=1)

# %%
df2=df2.drop('analysis_url', axis=1)

# %%
df2=df2.drop('track_href', axis=1)

# %%
df2=df2.drop('type',axis=1)

# %%
df2=df2.drop(0,axis=1)

# %%
df2

# %%
df2

# %% [raw]
# Clusstering

# %%
K = range(2, 20)
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(df2)
    inertia.append(kmeans.inertia_)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')

# %%
from sklearn.metrics import silhouette_score
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(df2)
    silhouette.append(silhouette_score(df2, kmeans.predict(df2)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Slhouette score showing the optimal k')

# %%
df2

# %%
from sklearn.preprocessing import StandardScaler

transformer = StandardScaler().fit(df2)
df2_standardized = transformer.transform(df2)
print(df2_standardized.shape)
audio_features = pd.DataFrame(df2_standardized, columns=df2.columns)

# %%
from sklearn import cluster, datasets

from matplotlib.lines import Line2D


kmeans = cluster.KMeans(n_clusters=10)
kmeans.fit(df2)
pred = kmeans.predict(df2)
pred

# %%
pd.Series(pred).value_counts().sort_index()

# %%
df['cluster'] = pred

# %%
#df = df.drop('URI', axis=1)

# %%
#df = df.drop('Audio Features', axis=1)

# %%
df

# %%
df.to_csv('Song_cluster.csv',index=False)
audio_features.to_csv('Audio_features.csv',index=False)
songs.to_csv('top100.csv',index=False)
# Pickle the KMeans model and the predictions
pickle.dump(kmeans, open('model.p', 'wb'))
pickle.dump(transformer, open('transformer.p','wb'))

# %%
song_title = input("Enter the song title: ")

# %%
x = random.randint(0,100)
# check if the song is in the DataFrame
if song_title in songs['title'].values:
    # if the song is in the DataFrame, recommend a different song
    recommended_song = songs.loc[songs['title'] != song_title, 'title'].iloc[x]
    print("You might like:", recommended_song)
    
else:
    track_uri = search_track(sp, "song_title")
    audio_features = get_audio_features(sp, track_uri)
    audio_feats = create_audio_features_df(audio_features)
    track_cluster = predict_track_cluster(kmeans, audio_feats)
    display_recommendations(df, track_cluster)

    
#if song_artist in songs['artist'].values:
    #recommended_artist = songs.loc[songs['artist'] != song_artist, 'artist'].iloc[x]
    #print ("You might like:", recommended_artist)
#else: 
    #print("Sorry,we cannot recommend an artist.")
# Out:
# /Users/meysouromezzine/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but KMeans was fitted without feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
song_title

# %%
track = sp.search(q=song_title)
track_uri = [track['tracks']['items'][0]['uri']]

print(track_uri)
audio_features = (sp.audio_features(track_uri))
# convert list to pandas DataFrame
audio_features_df = pd.DataFrame(audio_features)

# select numeric columns
audio_feats = audio_features_df.select_dtypes(include='number')
audio_feats
track_cluster = kmeans.predict(audio_feats).tolist()
track_cluster

for x in track_cluster:
    rec = df[(df['cluster'] == x)]
    display(rec.sample())

# %%
def search_track(sp, song_title):
    track = sp.search(q=song_title)
    track_uri = [track['tracks']['items'][0]['uri']]
    return track_uri

def get_audio_features(sp, track_uri):
    audio_features = sp.audio_features(track_uri)
    return audio_features

def create_audio_features_df(audio_features):
    audio_features_df = pd.DataFrame(audio_features)
    audio_feats = audio_features_df.select_dtypes(include='number')
    return audio_feats

def predict_track_cluster(kmeans, audio_feats):
    track_cluster = kmeans.predict(audio_feats)
    return track_cluster

def display_recommendations(df, track_cluster):
    rec = df[(df['cluster'] == track_cluster[0])].sample().reset_index(drop=True)
        #display(rec[['Track','Artist']])
        
    print('My recommendation is '+ str(rec['Track'][0]) + 'from the artist ' + str(rec['Artist'][0]))
